# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddy165/AI-ML-WORKSHOP/blob/main/Colab%20Notebooks/EXCERCISE/2.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u"This is the first sentence. This is another sentence. this is the last sentence.")
for sent in doc.sents:
    print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# this is the last sentence.

# %%
print(doc[1])
# Out:
# is

# %%
sentences = list(doc.sents)
print(sentences[1])
# Out:
# This is another sentence.

# %%
doc_sents = [sent for sent in doc.sents]
doc_sents
# Out:
# [This is the first sentence.,
#  This is another sentence.,
#  this is the last sentence.]

# %%
print(doc_sents[1])
# Out:
# This is another sentence.

# %%
type(doc_sents[1])
# Out:
# spacy.tokens.span.Span

# %%
print(doc_sents[1].start,doc_sents[1].end)
# Out:
# 6 11

# %%
doc2 = nlp(u'This is the first sentence. This is another sentence. This is the last sentence')
for token in doc2:
    print(token.is_sent_start, ' '+token.text)
# Out:
# True  This
# False  is
# False  the
# False  first
# False  sentence
# False  .
# True  This
# False  is
# False  another
# False  sentence
# False  .
# True  This
# False  is
# False  the
# False  last
# False  sentence

# %%
doc2 = nlp(u'This is the first sentence. This is another sentence. This is the last sentence')
for token in doc2:
    print(token.is_sent_end, ' '+token.text)
# Out:
# False  This
# False  is
# False  the
# False  first
# False  sentence
# True  .
# False  This
# False  is
# False  another
# False  sentence
# True  .
# False  This
# False  is
# False  the
# False  last
# True  sentence

# %%
doc = nlp(u'"Management is doing things right; Leadership is doing the right things." -Peter Drucker')
for sent in doc.sents:
    print(sent)
    print('\n')
# Out:
# "Management is doing things right; Leadership is doing the right things."
#
#
# -Peter Drucker

# %%
doc
# Out:
# "Management is doing things right; Leadership is doing the right things." -Peter Drucker

# %%
doc[:-1]
# Out:
# "Management is doing things right; Leadership is doing the right things." -Peter

# %%
doc[:-2]
# Out:
# "Management is doing things right; Leadership is doing the right things."

# %%
from spacy.language import Language
@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text == ';':
            doc[token.i+1].is_sent_start = True
    return doc

# %%
nlp.add_pipe("set_custom_boundaries",before='parser')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'set_custom_boundaries', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc4 = nlp(u'"Management is doing things right; Leadership is doing the right things." -Peter Drucker')
for sent in doc4.sents:
    print(sent)
# Out:
# "Management is doing things right;
# Leadership is doing the right things."
# -Peter Drucker

# %%
doc4 = nlp(u'"Management is doing things right; Leadership is doing the right things." -Peter Drucker')
for sent in doc4.sents:
    print(sent)
# Out:
# "Management is doing things right;
# Leadership is doing the right things."
# -Peter Drucker

# %%
doc4[4]
# Out:
# things

# %%
doc4[4].is_sent_start = True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1304327280.py in <cell line: 0>()
# ----> 1 doc4[4].is_sent_start = True
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokens/token.pyx in spacy.tokens.token.Token.is_sent_start.__set__()
#
# ValueError: [E043] Refusing to write to token.sent_start if its document is parsed, because this may cause inconsistent state.

# %%
nlp = spacy.load('en_core_web_sm')
mystring = u"This is a sentence.This is another.\n\nThis is the \n third sentence."
doc = nlp(mystring)
for sent in doc.sents:
    print([token.text for token in sent])
# Out:
# ['This', 'is', 'a', 'sentence', '.']
# ['This', 'is', 'another', '.', '\n\n']
# ['This', 'is', 'the', '\n ', 'third', 'sentence', '.']
