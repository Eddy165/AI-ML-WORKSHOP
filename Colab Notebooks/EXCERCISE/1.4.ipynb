# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddy165/AI-ML-WORKSHOP/blob/main/Colab%20Notebooks/EXCERCISE/1.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(u'Tesla is looking at buying U.S. startup for $6 million')
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
print(nlp.pipeline)
print(nlp.pipe_names)
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x78be67af3830>), ('tagger', <spacy.pipeline.tagger.Tagger object at 0x78be676740b0>), ('parser', <spacy.pipeline.dep_parser.DependencyParser object at 0x78be678d0f90>), ('attribute_ruler', <spacy.pipeline.attributeruler.AttributeRuler object at 0x78be6763cbd0>), ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer object at 0x78be6763c0d0>), ('ner', <spacy.pipeline.ner.EntityRecognizer object at 0x78be678d0f20>)]
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"Tesla isn't  looking into startups anymore.")
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#   SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
print(doc2)
print(doc2[0])
print(type(doc2))
print(doc2[0].pos_)
print(doc2[0].dep_)
print(spacy.explain('PROPN'))
print(spacy.explain('nsubj'))
# Out:
# Tesla isn't  looking into startups anymore.
# Tesla
# <class 'spacy.tokens.doc.Doc'>
# PROPN
# nsubj
# proper noun
# nominal subject

# %%
print(doc2[4].text)
print(doc2[4].lemma_) # Corrected to .lemma_ to get text lemma
print(doc2[4].pos_)
print(doc2[4].tag_ + ' / ' + spacy.explain(doc2[4].tag_))
print(doc2[0].text+': '+doc2[0].shape_)
print(doc[5].text+' : '+doc[5].shape_)
# Out:
# looking
# look
# VERB
# VBG / verb, gerund or present participle
# Tesla: Xxxxx
# U.S. : X.X.

# %%
print(doc2[0].is_alpha)
print(doc2[0].is_stop)
# Out:
# True
# False

# %%
doc3=nlp(u'Although commonly attributed to John Lennon from his song "Beautiful Boy", the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')
life_quote=doc3[1] # This is the token 'commonly'

print(f"Token: {life_quote.text}")
print(f"Lemma: {life_quote.lemma_}")
print(f"POS: {life_quote.pos_} / {spacy.explain(life_quote.pos_)}")
print(f"DEP: {life_quote.dep_} / {spacy.explain(life_quote.dep_)}")
print(f"Tag: {life_quote.tag_} / {spacy.explain(life_quote.tag_)}")
print(f"Shape: {life_quote.shape_}")
print(f"Is Alpha: {life_quote.is_alpha}")
print(f"Is Stop Word: {life_quote.is_stop}")
# Out:
# Token: commonly
# Lemma: commonly
# POS: ADV / adverb
# DEP: advmod / adverbial modifier
# Tag: RB / adverb
# Shape: xxxx
# Is Alpha: True
# Is Stop Word: False
