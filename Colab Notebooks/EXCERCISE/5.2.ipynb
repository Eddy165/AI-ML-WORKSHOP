# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddy165/AI-ML-WORKSHOP/blob/main/Colab%20Notebooks/EXCERCISE/5.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full=cv2.imread('/content/sammy.jpg')
full=cv2.cvtColor(full,cv2.COLOR_BGR2RGB)
plt.imshow(full)

# %%
face=cv2.imread('/content/sammy_face.jpg')
face=cv2.cvtColor(face,cv2.COLOR_BGR2RGB)

# %%
methods=['cv2.TM_CCOEFF','cv2.TM_CCOEFF_NORMED',
         'cv2.TM_CCORR','cv2.TM_CCORR_NORMED',
         'cv2.TM_SQDIFF','cv2.TM_SQDIFF_NORMED']
for m in methods:
  img=full.copy()
  method=eval(m)
  res=cv2.matchTemplate(img,face,method)
  min_val,max_val,min_loc,max_loc=cv2.minMaxLoc(res)

  if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
    top_left=min_loc
  else:
    top_left=max_loc
  height,width,channels=face.shape
  bottom_right=(top_left[0]+width,top_left[1]+height)
  cv2.rectangle(img,top_left,bottom_right,(0,0,255),10)

  plt.subplot(121)
  plt.imshow(res)
  plt.title('Result of template matching')
  plt.subplot(122)
  plt.imshow(img)
  plt.title('Detected Point')
  plt.suptitle(m)

# %%
plt.subplot(122)
plt.imshow(img)
plt.title('Detected Point')
plt.suptitle(m)

plt.show()
print('\n')
print('\n')
