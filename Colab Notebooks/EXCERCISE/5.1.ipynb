# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddy165/AI-ML-WORKSHOP/blob/main/Colab%20Notebooks/EXCERCISE/5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def adj_detect_face(img):
  face_img=img.copy()
  face_rects=face_cascade.detectMultiScale(face_img,scaleFactor=1.2,minNeighbors=5)
  for (x,y,w,h) in face_rects:
    cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
  return face_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nadia=cv2.imread('/content/Nadia_Murad.jpg',0)
denis=cv2.imread('/content/Denis_Mukwege.jpg',0)
solvay=cv2.imread('/content/solvay_conference.jpg',0)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
result=adj_detect_face(nadia)
plt.imshow(result)

# %%
result=adj_detect_face(solvay)
plt.imshow(result)

# %%
eye_cascade=cv2.CascadeClassifier('/content/haarcascade_eye.xml')

# %%
def detect_eyes(img):
  face_img=img.copy()
  # Use the globally defined eye_cascade and detect eyes
  eyes = eye_cascade.detectMultiScale(face_img, scaleFactor=1.2, minNeighbors=5)
  for (x,y,w,h) in eyes:
    cv2.rectangle(face_img,(x,y),(x+w,y+h),(255,255,255),10)
  return face_img

result=detect_eyes(nadia)
plt.imshow(result,cmap='gray')

# %%
result=detect_eyes(solvay)
plt.imshow(result,cmap='gray')
