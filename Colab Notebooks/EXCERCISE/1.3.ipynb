# %% [markdown]
# <a href="https://colab.research.google.com/github/Eddy165/AI-ML-WORKSHOP/blob/main/Colab%20Notebooks/EXCERCISE/1.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="The agents phone no is 12345678 call soon!"
'phone'in text
# Out:
# True

# %%
import re
pattern='phone'
match =re.search(pattern,text)
match
# Out:
# <re.Match object; span=(11, 16), match='phone'>

# %%
match.span()
text='my phone is a new phone'
match =re.search('phone',text)
match.span()
# Out:
# (3, 8)

# %%
matches =re.findall('phone',text)
matches
# Out:
# ['phone', 'phone']

# %%
len(matches)
# Out:
# 2

# %%
text='my telephone no is 409-55-123'
phone = re.search(r'\d\d\d-\d\d\d-\d\d\d\d', text)

# %%
print(phone)
# Out:
# None

# %%
re. search (r"man|woman","this man was here")
# Out:
# <re.Match object; span=(5, 8), match='man'>

# %%
re. search (r"man|woman","this woman was here")
# Out:
# <re.Match object; span=(5, 10), match='woman'>

# %%
re.findall(r".at","the cat in the hat sat here")
# Out:
# ['cat', 'hat', 'sat']

# %%
re.findall(r"...at","the cat in the hat sat here")
# Out:
# ['e cat', 'e hat']

# %%
text='inly find the hypen-words in the sentence'

# %%
re.findall(r'[\w]+-[\w]+',text)
# Out:
# ['hypen-words']

# %%
text="hello, would you like some cat fish"
re.findall(r"h","hello, would you like some cat fish")
# Out:
# ['h', 'h']
